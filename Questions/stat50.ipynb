# %% [markdown]
# Level 1: Central Tendency
# Q1
# Find mean.
#
# Q2
# Find median.
#
# Q3
# Find mode.
#
# Q4
# When is median preferred over mean?
#
# Q5
# What happens to mean when outlier added?
#
# Level 2: Dispersion
# Q6
# Range
#
# Q7
# Variance
#
# Q8
# Standard deviation
#
# Q9
# Interpret standard deviation.
#
# Q10
# High SD vs Low SD.
#
# Level 3: Percentiles
# Q11
# 25th percentile
#
# Q12
# 50th percentile
#
# Q13
# 75th percentile
#
# Q14
# IQR
#
# Q15
# Outlier using IQR rule
#
# Level 4: Probability
# Q16
# P(A)
#
# Q17
# P(A∩B)
#
# Q18
# P(A∪B)
#
# Q19
# Independent events
#
# Q20
# Mutually exclusive events
#
# Level 5: Conditional Probability
# Q21
# P(A|B)
#
# Q22
# Bayes Theorem
#
# Q23
# Medical test example
#
# Q24
# False positive
#
# Q25
# False negative
#
# Level 6: Distributions
# Q26
# Normal Distribution
#
# Q27
# Properties of Bell Curve
#
# Q28
# 68-95-99.7 Rule
#
# Q29
# Skewness
#
# Q30
# Positive vs Negative Skew
#
# Level 7: Sampling
# Q31
# Population
#
# Q32
# Sample
#
# Q33
# Sampling Bias
#
# Q34
# Random Sampling
#
# Q35
# Central Limit Theorem
#
# Level 8: Hypothesis Testing
# Q36
# Null Hypothesis
#
# Q37
# Alternative Hypothesis
#
# Q38
# p-value
#
# Q39
# Type I Error
#
# Q40
# Type II Error
#
# Level 9: Correlation
# Q41
# Positive Correlation
#
# Q42
# Negative Correlation
#
# Q43
# Zero Correlation
#
# Q44
# Pearson Correlation
#
# Q45
# Correlation vs Causation
#
# Level 10: ML-Oriented Statistics
# Q46
# Covariance
#
# Q47
# Correlation Matrix
#
# Q48
# Feature Scaling
#
# Q49
# Z-Score
#
# Q50
# Outlier Detection using Z-score

# %%
data = [10,20,30,40,50]

import numpy as np
from scipy import stats

data=[10,20,30,40,50]

# Mean
np.mean(data)

# Median
np.median(data)

# Mode
stats.mode(data)

# Range
max(data)-min(data)

# Variance
np.var(data)

# Std
np.std(data)

# Percentiles
np.percentile(data,25)
np.percentile(data,50)
np.percentile(data,75)

# IQR
q3-q1

# Correlation
np.corrcoef(x,y)

# Covariance
np.cov(x,y)

# Z-score
stats.zscore(data)

# %% [markdown]
# #Most IMP
# 1.Mean vs Median vs Mode
# 2.Variance vs Standard Deviation
# 3.Normal Distribution
# 4.68-95-99.7 Rule
# 5.Central Limit Theorem
# 6.Correlation vs Covariance
# 7.Correlation vs Causation
# 8.p-value
# 9.Type I vs Type II Error
# 10.Bayes Theorem
# 11.Z-score
# 12.Outlier Detection
