# %% [markdown]
# Level 1: ML Fundamentals (Q1-Q20)
# Q1
# What is Machine Learning?
#
# Q2
# Types of ML?
#
# Q3
# Supervised Learning
#
# Q4
# Unsupervised Learning
#
# Q5
# Reinforcement Learning
#
# Q6
# Features vs Target
#
# Q7
# Training Data
#
# Q8
# Testing Data
#
# Q9
# Validation Data
#
# Q10
# Train-Test Split
#
# Q11
# Overfitting
#
# Q12
# Underfitting
#
# Q13
# Bias
#
# Q14
# Variance
#
# Q15
# Bias-Variance Tradeoff
#
# Q16
# Cross Validation
#
# Q17
# Data Leakage
#
# Q18
# Feature Engineering
#
# Q19
# Feature Selection
#
# Q20
# Pipeline
#
# Level 2: Linear Regression (Q21-Q35)
# Q21
# What problem does it solve?
#
# Q22
# Regression vs Classification
#
# Q23
# Equation
#
# Q24
# Slope
#
# Q25
# Intercept
#
# Q26
# Cost Function
#
# Q27
# MSE
#
# Q28
# RMSE
#
# Q29
# MAE
#
# Q30
# R² Score
#
# Q31
# Adjusted R²
#
# Q32
# Gradient Descent
#
# Q33
# Learning Rate
#
# Q34
# Multicollinearity
#
# Q35
# Assumptions of Linear Regression
#
# Level 3: Logistic Regression (Q36-Q45)
# Q36
# Classification problem
#
# Q37
# Sigmoid Function
#
# Q38
# Output range
#
# Q39
# Decision Boundary
#
# Q40
# Log Loss
#
# Q41
# Binary Classification
#
# Q42
# Multiclass Classification
#
# Q43
# Precision
#
# Q44
# Recall
#
# Q45
# F1 Score
#
# Level 4: KNN (Q46-Q52)
# Q46
# How KNN works
#
# Q47
# Choosing K
#
# Q48
# Distance Metrics
#
# Q49
# Euclidean Distance
#
# Q50
# Curse of Dimensionality
#
# Q51
# Advantages
#
# Q52
# Disadvantages
#
# Level 5: Decision Tree (Q53-Q60)
# Q53
# How tree splits data
#
# Q54
# Entropy
#
# Q55
# Information Gain
#
# Q56
# Gini Impurity
#
# Q57
# Root Node
#
# Q58
# Leaf Node
#
# Q59
# Overfitting in Trees
#
# Q60
# Tree Pruning
#
# Level 6: Random Forest (Q61-Q67)
# Q61
# What is Random Forest
#
# Q62
# Bootstrap Sampling
#
# Q63
# Bagging
#
# Q64
# Feature Randomness
#
# Q65
# Advantages
#
# Q66
# Disadvantages
#
# Q67
# Feature Importance
#
# Level 7: Naive Bayes (Q68-Q72)
# Q68
# Bayes Theorem
#
# Q69
# Why "Naive"
#
# Q70
# Types of Naive Bayes
#
# Q71
# Advantages
#
# Q72
# Disadvantages
#
# Level 8: SVM (Q73-Q78)
# Q73
# Support Vector
#
# Q74
# Hyperplane
#
# Q75
# Margin
#
# Q76
# Kernel Trick
#
# Q77
# Linear vs Non-linear SVM
#
# Q78
# Advantages
#
# Level 9: Clustering (Q79-Q85)
# Q79
# K-Means
#
# Q80
# Centroid
#
# Q81
# Elbow Method
#
# Q82
# Hierarchical Clustering
#
# Q83
# DBSCAN
#
# Q84
# Silhouette Score
#
# Q85
# Applications
#
# Level 10: Model Evaluation (Q86-Q100)
# Q86
# Confusion Matrix
#
# Q87
# TP
#
# Q88
# TN
#
# Q89
# FP
#
# Q90
# FN
#
# Q91
# Accuracy
#
# Q92
# Precision
#
# Q93
# Recall
#
# Q94
# F1 Score
#
# Q95
# ROC Curve
#
# Q96
# AUC
#
# Q97
# Class Imbalance
#
# Q98
# Stratified Sampling
#
# Q99
# Hyperparameter Tuning
#
# Q100
# Grid Search vs Random Search

# %% [markdown]
# #Most IMP
# 1. Overfitting
# 2. Underfitting
# 3. Bias-Variance
# 4. Cross Validation
# 5. Data Leakage
# 6. Linear Regression
# 7. MSE/RMSE/MAE
# 8. Logistic Regression
# 9. Precision
# 10. Recall
# 11. F1 Score
# 12. KNN
# 13. Decision Tree
# 14. Random Forest
# 15. Feature Importance
# 16. K-Means
# 17. Elbow Method
# 18. Confusion Matrix
# 19. ROC-AUC
# 20. Hyperparameter Tuning
